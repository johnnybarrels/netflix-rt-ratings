# %%
import requests
import json
import pandas as pd
import re
from bs4 import BeautifulSoup
from datetime import datetime
from timeit import default_timer as timer

# %% [markdown]
# ___
# # Netflix Ratings
# ## Johnny Barrett
# ### Feb 2020
# This notebook builds a dataframe of all programs available on Netflix in a given region, with their corresponding IMDb and Rotten Tomatoes scores.

# %% [markdown]
# ___
# ## 1. Building Netflix DataFrame from uNoGS API
#
# Please note: To use this notebook, you will need to acquire an API key from https://rapidapi.com/unogs/api/unogs. An API key grants you 100 free requests per day. Also, each individual request is limited to only 100 results (programs), so to get the full list of programs for your region you will need to:
# - Head to https://unogs.com
# - Select only the region(s) you are interested in
# - Observe how many pages of results there are (there are 100 results per page)
# - Set the variable `PAGES` to this number
#
# The get_catalogue function will then perform a request for each 100 results (each 'page') until all results have been collected.

# %%
RAPIDAPI_KEY = "871eb26902msh3eb929fcaab20c6p11065fjsnecd4f288ad44"

# %%
url = "https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi"
COUNTRY_CODE = '23'  # Australia country code
PAGES = 56  # Number of pages for Australia region
HEADERS = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': RAPIDAPI_KEY
    }

# %%
def get_catalogue(pages, country_code, headers):
    '''Builds pandas DataFrame of all available Netflix programs in given country_code region.
    Check unogs.com for the appropriate value for variable pages for your desired region.
    '''
    shows_data = []
    for i in range(1, pages+1):
        querystring = {'cl':country_code, 't':'ns', 'st':'adv', 'p': str(i)}
        response = requests.request("GET", url, headers=headers, params=querystring)
        json_to_dict = json.loads(response.text)
        shows_data.extend(json_to_dict['ITEMS'])
        print('-', end='')
    
    df = pd.DataFrame(shows_data)
    df.columns = ['NetflixID', 'Title', 'Image', 'Synopsis',
                  'IMDbRating', 'Type', 'ReleaseYear', 'Runtime',
                  'LargeImage', 'uNoGSDate', 'IMDbID', 'Download']
    df.set_index('NetflixID', inplace=True)
    
    print('\nCatalogue received successfully')
    
    return df

# %%
df = get_catalogue(PAGES, COUNTRY_CODE, HEADERS)
# Out:
# --------------------------------------------------------
# Catalogue received successfully

# %%
df.shape
# Out:
# (5519, 11)

# %%
df.head()
# Out:
#                                                        Title  \
# NetflixID
# 81212488         ZZ TOP: THAT LITTLE OL&#39; BAND FROM TEXAS
# 81229511               Velvet Colecci&oacute;n: Grand Finale
# 81244455                               Pop, Lock &#39;n Roll
# 70019062             Nausica&auml; of the Valley of the Wind
# 81237761   Calico Critters: Everyone&#39;s Big Dream Flyi...
#
#                                                        Image  \
# NetflixID
# 81212488   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...
# 81229511   https://occ-0-2773-2774.1.nflxso.net/dnm/api/v...
# 81244455   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...
# 70019062   https://occ-0-2773-2774.1.nflxso.net/dnm/api/v...
# 81237761   https://occ-0-2705-2433.1.nflxso.net/dnm/api/v...
#
#                                                     Synopsis IMDbRating  \
# NetflixID
# 81212488   This documentary delves into the mystique behi...        7.3
# 81229511   During Christmas 1969, the impending sale of V...
# 81244455   An ambitious hip-hop dancer jeopardizes his ri...          0
# 70019062   Facing the destruction of her planet&#39;s nat...        8.1
# 81237761   In the Hazelnut Chipmunk Family, Dominic is a ...
#
#             Type ReleaseYear Runtime LargeImage   uNoGSDate     IMDbID  \
# NetflixID
# 81212488   movie        2019   1h30m             2020-03-01  tt9015306
# 81229511   movie        2020   1h22m             2020-03-01
# 81244455   movie        2017   1h27m             2020-03-01  tt2336014
# 70019062   movie        1984   1h57m             2020-03-01  tt0087544
# 81237761   movie        2019     11m             2020-02-29
#
#           Download
# NetflixID
# 81212488         0
# 81229511         0
# 81244455         0
# 70019062         0
# 81237761         0

# %% [markdown]
# ___
# ## 2. Data pre-processing
# Exploring the data and resolving some formatting issues

# %%
def fix_punc(df, code, punc):
    '''Fix puncuation codes'''
    df['Title'] = df['Title'].str.replace(code, punc)
    df['Synopsis'] = df['Synopsis'].str.replace(code, punc)

# %%
fix_punc(df, "&#39;", "'")
fix_punc(df, "&rsquo;", "'")
fix_punc(df, "&ndash;", "-")

# %%
# Ensuring all Type == 'movie' are lowercase
df['Type'] = df['Type'].str.replace('Movie', 'movie')

# %%
def search(df, title):
    '''Simple title search function'''
    return df[df['Title'].str.lower().str.contains(title.lower())].sort_values('IMDbRating', ascending=False)

# %%
search(df, 'avatar')  # example
# Out:
#                                 Title  \
# NetflixID
# 70142405   Avatar: The Last Airbender
# 81175361            The King's Avatar
#
#                                                        Image  \
# NetflixID
# 70142405   https://occ-0-2717-360.1.nflxso.net/dnm/api/v6...
# 81175361   https://occ-0-768-769.1.nflxso.net/dnm/api/v6/...
#
#                                                     Synopsis IMDbRating  \
# NetflixID
# 70142405   Siblings Katara and Sokka wake young Aang from...        9.2
# 81175361   When an elite gamer is forced out of his profe...          0
#
#              Type ReleaseYear Runtime  \
# NetflixID
# 70142405   series        2005
# 81175361   series        2019
#
#                                                  LargeImage   uNoGSDate  \
# NetflixID
# 70142405   http://cdn1.nflximg.net/images/5561/11315561.jpg  2015-04-14
# 81175361                                                     2019-08-16
#
#                IMDbID Download
# NetflixID
# 70142405    tt0417299        0
# 81175361   tt10736726        0

# %% [markdown]
# ___
# ## 3. Scraping Rotten Tomatoes Ratings
# Now, we use the Title and Type of each program to build a Rotten Tomatoes URL and attempt to scrape ratings. Whenever we cannot aquire a rating from RT, we simply continue (leaving a NaN value). There are a range of reasons why this can happen, for instance:
# - Some shows may simply not be listed on Rotten Tomatoes
# - Some shows might have a Critic rating but not an Audience rating, or vice versa
# - Some movies and shows, predominantly remakes, will have the year of release after their name in the URL. This algorithm does not account for this
# - Special characters in the movie title can affect the URL building function
# - The URL building function could be improved, with more focus on edge cases
#
# First we build the functions we need to search through the HTML of each program's review site:

# %%
def get_critic(soup):
    '''If found, return Critic score for given title from Rotten Tomatoes.
    Return None otherwise.'''
    critic_badge = soup.find('div', {'class': 'mop-ratings-wrap__half'})
    try:
        critic_score = int(critic_badge.find('span', {'class': 'mop-ratings-wrap__percentage'}).contents[0].strip().strip('%'))
    except AttributeError:  # If score not found
        return
    return critic_score

# %%
def get_audience(soup):
    '''If found, return Audience score for given title from Rotten Tomatoes.
    Return None otherwise.'''
    audience_badge = soup.find('div', {'class': 'mop-ratings-wrap__half audience-score'})
    if audience_badge:
        try:
            audience_score = int(audience_badge.find('span', {'class': 'mop-ratings-wrap__percentage'}).contents[0].strip().strip('%'))
        except AttributeError:  # If score not found
            return
        return audience_score

# %% [markdown]
# And some other useful functions:

# %%
def percent_na(df):
    '''View the percentage of missing values per column'''
    return round(df.isnull().mean() * 100, 2)

# %%
def process_time(seconds):
    '''Transform seconds into hh:mm:ss'''
    mins, secs = divmod(seconds, 60)
    hrs, mins = divmod(mins, 60)
    return f'{int(hrs):02d}:{int(mins):02d}:{int(secs):02d}'

# %% [markdown]
# The `get_rt_scores` function builds a Rotten Tomatoes URL and scrapes the site for it's ratings. This can take some time (for Australia region, roughly 2 hours).

# %%
def get_rt_scores(df):
    '''For each title in DataFrame, build Rotten Tomatoes URL,
    attempt to retrieve scores and add to DataFrame.'''
    
    start = timer()
    tomato_base_url = 'https://www.rottentomatoes.com/'

    for ID in df.index:
        if df.loc[ID, 'Type'] == 'movie':
            tomato_url = tomato_base_url + 'm/'
        elif df.loc[ID, 'Type'] == 'series':
            tomato_url = tomato_base_url + 'tv/'
        tomato_url += re.sub(':', '', re.sub(' ', '_', re.sub("'", '_', re.sub(',', '', df.loc[ID, 'Title'])))).lower()
        soup = BeautifulSoup(requests.get(tomato_url).text)

        df.loc[ID, 'RT Critic'] = get_critic(soup)
        df.loc[ID, 'RT Audience'] = get_audience(soup)
        
        print('.', end='')
    
    end = timer()
    print(f'\nCompleted in {process_time(end-start)}')

# %%
get_rt_scores(df)

# %% [markdown]
# ### Saving new df to csv for later use

# %%
date_today = str(datetime.now().date())
df.to_csv(f'Netflix_Aus_Ratings_{date_today}.csv')

# %% [markdown]
# ___
# ## 4. Exploring our new DataFrame

# %%
df.head()
# Out:
#                           Title  \
# NetflixID
# 81194454           She Did That
# 81055398   Faith, Hope and Love
# 81176204                 Thambi
# 81234400                Tempted
# 81234382      Extraordinary You
#
#                                                        Image  \
# NetflixID
# 81194454   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...
# 81055398   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...
# 81176204   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...
# 81234400   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...
# 81234382   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...
#
#                                                     Synopsis  IMDbRating  \
# NetflixID
# 81194454   Go inside the lives of extraordinary, black fe...         NaN
# 81055398   After shattering losses, a recent divorc&eacut...         NaN
# 81176204   As a tip leads a local politician to his long-...         7.4
# 81234400   Love is just a game for a chaebol heir who agr...         NaN
# 81234382   A teen seeks to change the fate that's been se...         8.2
#
#              Type  ReleaseYear Runtime LargeImage   uNoGSDate      IMDbID  \
# NetflixID
# 81194454    movie         2019   1h10m        NaN  2020-02-04         NaN
# 81055398    movie         2019   1h46m        NaN  2020-02-04         NaN
# 81176204    movie         2019   2h27m        NaN  2020-02-02  tt10468636
# 81234400   series         2018     NaN        NaN  2020-02-01         NaN
# 81234382   series         2019     NaN        NaN  2020-02-01  tt10826102
#
#            Download  RT Critic  RT Audience
# NetflixID
# 81194454        0.0        NaN          NaN
# 81055398        0.0       80.0         96.0
# 81176204        0.0        NaN         57.0
# 81234400        0.0        NaN          NaN
# 81234382        0.0        NaN          NaN

# %% [markdown]
# First, let's select only the columns we want:

# %%
df2 = df[['Title', 'Type', 'ReleaseYear', 'Synopsis', 'Runtime', 'Image', 'IMDbRating', 'RT Critic', 'RT Audience']]
df2.head()
# Out:
#                           Title    Type  ReleaseYear  \
# NetflixID
# 81194454           She Did That   movie         2019
# 81055398   Faith, Hope and Love   movie         2019
# 81176204                 Thambi   movie         2019
# 81234400                Tempted  series         2018
# 81234382      Extraordinary You  series         2019
#
#                                                     Synopsis Runtime  \
# NetflixID
# 81194454   Go inside the lives of extraordinary, black fe...   1h10m
# 81055398   After shattering losses, a recent divorc&eacut...   1h46m
# 81176204   As a tip leads a local politician to his long-...   2h27m
# 81234400   Love is just a game for a chaebol heir who agr...     NaN
# 81234382   A teen seeks to change the fate that's been se...     NaN
#
#                                                        Image  IMDbRating  \
# NetflixID
# 81194454   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...         NaN
# 81055398   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...         NaN
# 81176204   https://occ-0-299-300.1.nflxso.net/dnm/api/v6/...         7.4
# 81234400   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         NaN
# 81234382   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         8.2
#
#            RT Critic  RT Audience
# NetflixID
# 81194454         NaN          NaN
# 81055398        80.0         96.0
# 81176204         NaN         57.0
# 81234400         NaN          NaN
# 81234382         NaN          NaN

# %% [markdown]
# How many ratings did we get?

# %%
percent_na(df2)
# Out:
# Title           0.00
# Type            0.00
# ReleaseYear     0.00
# Synopsis        0.02
# Runtime        34.49
# Image           0.00
# IMDbRating     17.75
# RT Critic      73.02
# RT Audience    58.17
# dtype: float64

# %%
df2.sort_values(['RT Audience', 'RT Critic'], ascending=False).head(20)
# Out:
#                                             Title    Type  ReleaseYear  \
# NetflixID
# 80213588                    The Confession Killer  series         2019
# 81021633                         The Last Animals   movie         2017
# 80190097             November 13: Attack on Paris  series         2018
# 80213655           The Honeymoon Stand Up Special  series         2018
# 80175348       Kantaro: The Sweet Tooth Salaryman  series         2017
# 80058424           John Mulaney: The Comeback Kid   movie         2015
# 80043049   Anthony Jeselnik: Thoughts and Prayers   movie         2015
# 70157495                              Black Books  series         2000
# 80209796                          Meditation Park   movie         2017
# 80093103                   Palm Trees in the Snow   movie         2015
# 81002391                                   Broken  series         2019
# 70140378                               Doc Martin  series         2004
# 80189024                       The Story of Diana  series         2017
# 80221210                              Brotherhood  series         2019
# 80217594          I'm with the Band: Nasty Cherry  series         2019
# 81004322                       Million Pound Menu  series         2018
# 81159258                     Crash Landing on You  series         2019
# 81019391                           Triad Princess  series         2019
# 81083590                       Home for Christmas  series         2019
# 80216180                          Dino Girl Gauko  series         2019
#
#                                                     Synopsis Runtime  \
# NetflixID
# 80213588   Henry Lee Lucas rose to infamy when he confess...     NaN
# 81021633   This sobering documentary highlights the poach...   1h31m
# 80190097   Survivors and first responders share personal ...     NaN
# 80213655   Impending parenthood does funny things to Nata...     NaN
# 80175348   Elite publishing sales rep Kantaro wraps up hi...     NaN
# 80058424   Armed with boyish charm and a sharp wit, the f...    1h1m
# 80043049   There's no subject too dark as the comedian sk...     59m
# 70157495   A misanthropic bookshop owner named Bernard Bl...     NaN
# 80209796   An elderly immigrant matriarch from Hong Kong ...   1h34m
# 80093103   Finding a tantalizing clue in an old letter, a...   2h42m
# 81002391   This investigative docuseries shows how neglig...     NaN
# 70140378   Crippled by a sudden fear of blood, a curmudge...     NaN
# 80189024   Explore the remarkable life and private strugg...     NaN
# 80221210   An honest lawyer reaches a moral crossroads af...     NaN
# 80217594   In an unfiltered, intimate docuseries, pop sta...     NaN
# 81004322   Next-gen restaurateurs get the chance to open ...     NaN
# 81159258   A paragliding mishap drops a South Korean heir...     NaN
# 81019391   After jostling her way into a gig as a celebri...     NaN
# 81083590   Tired of the constant comments on her relation...     NaN
# 80216180   When she gets angry, middle schooler Naoko tur...     NaN
#
#                                                        Image  IMDbRating  \
# NetflixID
# 80213588   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         NaN
# 81021633   https://occ-0-753-1360.1.nflxso.net/dnm/api/v6...         8.4
# 80190097   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         NaN
# 80213655   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         NaN
# 80175348   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         NaN
# 80058424   http://occ-0-1952-2433.1.nflxso.net/dnm/api/v6...         7.9
# 80043049   http://occ-0-1952-2433.1.nflxso.net/dnm/api/v6...         7.8
# 70157495   https://occ-0-753-1360.1.nflxso.net/dnm/api/v6...         8.5
# 80209796   http://occ-0-753-1360.1.nflxso.net/dnm/api/v6/...         7.2
# 80093103   https://occ-0-768-769.1.nflxso.net/dnm/api/v6/...         7.4
# 81002391   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         0.0
# 70140378   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         8.3
# 80189024   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         8.1
# 80221210   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         0.0
# 80217594   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         NaN
# 81004322   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         6.5
# 81159258   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         NaN
# 81019391   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         NaN
# 81083590   https://occ-0-1952-2433.1.nflxso.net/dnm/api/v...         7.8
# 80216180   https://occ-0-2851-1432.1.nflxso.net/dnm/api/v...         NaN
#
#            RT Critic  RT Audience
# NetflixID
# 80213588       100.0        100.0
# 81021633       100.0        100.0
# 80190097       100.0        100.0
# 80213655       100.0        100.0
# 80175348       100.0        100.0
# 80058424       100.0        100.0
# 80043049       100.0        100.0
# 70157495       100.0        100.0
# 80209796        89.0        100.0
# 80093103        86.0        100.0
# 81002391        84.0        100.0
# 70140378        82.0        100.0
# 80189024        80.0        100.0
# 80221210        79.0        100.0
# 80217594        60.0        100.0
# 81004322        57.0        100.0
# 81159258         NaN        100.0
# 81019391         NaN        100.0
# 81083590         NaN        100.0
# 80216180         NaN        100.0

# %% [markdown]
# ___
# ## 5. Future Work & Extensions
# There are a range of ways we could extend beyond this project, including:
# - Devising an improved URL building function
# - Building a web-based front-end for the new dataframe
# - Developing a metric that takes into considerationg the number of reviews that contribute to a rating (this metric is available on RT). For example: we might consider that a program with 100,000 reviews leading to a rating of 85 is a more significant result than a program with 2 reviews with a rating of 90
